# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Danish Karim. I want to be a Data Scientist.**

# %% [markdown]
# *I am interested in Data Science because I want to to solve real-world problems using the Data Science techniques.*

# %% [markdown]
# ### In the cell below. The code will print a greeting sentence.

# %%
print('Welcome to Data Science')
# Out:
# Welcome to Data Science

# %% [markdown]
# A scientist can learn one or more of the following programming languages:
#
# * Python
# * R
# * Julia

# %% [markdown]
# This is a |Math Courses  |Programming Languages|
# |:---          |                 :---|
# |Statistics    |Python               |
# |Linear Algebra|R                    |
# |Calculus      |Julia                |
